# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# Load and preprocess the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# architecture of the Vanilla Autoencoder
input_size = 784  # 28x28 pixels
encoding_dim = 32

# %%
# Encoder
input_img = Input(shape=(input_size,))
encoded = Dense(encoding_dim, activation='relu')(input_img)

# %%
# Decoder
decoded = Dense(input_size, activation='sigmoid')(encoded)

# %%
# Autoencoder model
autoencoder = Model(input_img, decoded)

# %%
# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 784)               25872
#
# =================================================================
# Total params: 50992 (199.19 KB)
# Trainable params: 50992 (199.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2766 - val_loss: 0.1904
# Epoch 2/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1701 - val_loss: 0.1524
# Epoch 3/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1438 - val_loss: 0.1333
# Epoch 4/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1279 - val_loss: 0.1206
# Epoch 5/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1175 - val_loss: 0.1122
# Epoch 6/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1107 - val_loss: 0.1070
# Epoch 7/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1060 - val_loss: 0.1028
# Epoch 8/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1025 - val_loss: 0.0997
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0998 - val_loss: 0.0975
# Epoch 10/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0980 - val_loss: 0.0959
# Epoch 11/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0966 - val_loss: 0.0947
# Epoch 12/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0958 - val_loss: 0.0941
# Epoch 13/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0952 - val_loss: 0.0936
# Epoch 14/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0948 - val_loss: 0.0933
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0945 - val_loss: 0.0929
# Epoch 16/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0943 - val_loss: 0.0929
# Epoch 17/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0941 - val_loss: 0.0927
# Epoch 18/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0939 - val_loss: 0.0924
# Epoch 19/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 20/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0936 - val_loss: 0.0922
# Epoch 21/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0935 - val_loss: 0.0922
# Epoch 22/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0934 - val_loss: 0.0920
# Epoch 23/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 24/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 25/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 26/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 27/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 28/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 29/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0930 - val_loss: 0.0917
# Epoch 30/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 31/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0929 - val_loss: 0.0916
# Epoch 32/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 33/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 34/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 35/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 36/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 37/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 38/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 39/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 40/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 41/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 42/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 43/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 44/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 45/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 46/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 47/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 48/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 49/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 50/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0925 - val_loss: 0.0914

# %%
# Encode and decode some digits
decoded_imgs = autoencoder.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
# Plotting original and reconstructed images
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original Images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed Images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
